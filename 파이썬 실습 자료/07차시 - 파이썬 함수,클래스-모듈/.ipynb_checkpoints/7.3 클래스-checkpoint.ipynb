# %% [markdown]
# ### 7.3 클래스

# %% [markdown]
# ### 7.3.1 클래스 시작하기

# %% [markdown]
# Python에서는 모든 것이 객체(object)와 클래스(class)이며 이러한 모든 객체는 클래스로 정의되어 있습니다.
#
# 숫자, 문자, 문자열 등을 기초(Primitive) 객체입니다.
#
# 객체는 데이터(변수 또는 속성)와 코드(함수 또는 메소드)를 포함한다.
#
# 객체는 class에 의해 생성되고 실제로 Instance화 됩니다.

# %% [markdown]
# class는 객체를 만드는 붕어빵 틀입니다, class를 통해 여러개의 객체를 생성
#
# 객체의 초기화(생성자를 통해서,constructor)를 위해 class 내부에 __init__함수 선언
#
# __init__ 함수의 첫 번째 매개변수는 self, self는 특정 객체 자신을 의미
#
# Person 클래스의 정의를 호출합니다.
#
# 새로운 객체를 메모리에 생성, 붕어빵틀에 재료를 넣고 앙꼬를 널고 만듭니다.

# %% [markdown]
# ![image.png](attachment:d226c8c9-cd36-4b37-9325-10ff36a1bcab.png)

# %% [markdown]
# ![image.png](attachment:c39f0366-7391-4abb-bcc0-8156606f3393.png)

# %% [markdown]
# ![image.png](attachment:665771dc-7153-4985-beac-548f1dd5c18e.png)

# %%
class Person(): ### 일반적으로 클래스는 대문자로 시작한다...
    # 객체 초기화를 위한 __init__ 함수
    def __init__(self, name,age,gender,address):  #초기화 정의를 했다.....####생성자
        self.name = name
        self.age = age
        self.gender = gender    
        self.address = address    
        
        
if __name__ == "__main__": ##entry point... 시작점...    
    someone = Person("nick",22,'male')
    
    print(someone.name)
    print(someone.age)
    print(someone.gender)
# Out:
# nick
# 22
# male

# %%
class Person(): ### 일반적으로 클래스는 대문자로 시작한다...
    # 객체 초기화를 위한 __init__ 함수
    def __init__(self, name,age,gender,address):  #초기화 정의를 했다.....####생성자
        self.name = name
        self.age = age
        self.gender = gender    
        self.address = address  
        
someone = Person("nick",22,'male','seoul')
    
print(someone.name)
print(someone.age)
print(someone.gender)
# Out:
# nick
# 22
# male

# %% [markdown]
# ![image.png](attachment:34d60f7f-e067-456c-b20d-7ec5868cce07.png)

# %% [markdown]
# ![image.png](attachment:d22032f5-68c0-4773-9040-53d4574f7ff8.png)

# %% [markdown]
# ![image.png](attachment:925e9052-054a-4151-b50c-2c22093a5677.png)

# %% [markdown]
# ### 돌발 문제
#
# 학생 오브젝트를 만들고 두명의 학생을 인스터스화(오브젝트)하고 그 Field를 출력하세요.

# %% [markdown]
# ### 7.3.2 파이썬 클래스 메소드 VS 인스턴스 메소드

# %%
class test:
    data = 10 # 클래스 속성
    
    def __init__(self, data): 
        self.data = data # 인스턴스 속성
        
    @classmethod #어노테이션...anotation...
    def printClass(cls): # 클래스 메소드
        print(cls.data)
        
    def printInstance(self): # 인스턴스 메소드
        print(self.data)

# %%
t = test('asdf') #오브젝트/인스턴스화 한다... 먼저

t.printClass() #그다음에 그 인스턴스 이름(변수) 이름.메소드
test.printClass() #@classmethod #어노테이션이 선언되어 있으면 인스턴스가 아닌 클래스 이름만으로 메소드를 실행할 수 있다...

#test.printInstance()

t = test('asdf')

t.printInstance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11852\218946472.py in <module>
# ----> 1 t = test('asdf')
#       2
#       3 t.printClass()
#       4 test.printClass()
#       5 test.printInstance()
#
# NameError: name 'test' is not defined

# %% [markdown]
# ### 7.3.3 모듈에 클래스파일로 만들기

# %% [markdown]
# 다음 내용을 프로젝트 폴더(c:\project)안에 person.py 파일로 저장

# %%
#person.py  
class Person:    # 클래스  
    def __init__(self, name, age, address):  
        self.name = name  
        self.age = age  
        self.address = address  
    
    def greeting(self):  
        print('안녕하세요, 저는 {0}입니다.'.format(self.name))

# %%
#모듈.클래스로 person 모듈의 클래스 사용
hong = Person('홍길동', 20, '서울시')
hong.greeting()
# Out:
# 안녕하세요, 저는 홍길동입니다.

# %% [markdown]
# ### 7.3.4 상속(Inheritance), 오버라이드(Override)

# %% [markdown]
# 기존의 클래스에 새로운 기능을 추가하거나 변경하여 코드의 재사용성을 높이는 객체지향언어의 개념
# 기존 클래스의 함수는 상속된 클래스에서 재정의(오버라이드) 할 수 있음
# 상위 클래스: 부모 클래스, 상위 클래스, 슈퍼(Super) 클래스, 베이스(Base) 클래스
# 하위 클래스: 자식 클래스, 하위 클래스, 서브(Sub) 클래스, 파생된(Derived) 클래스

# %%
class Car():
    def exclaim(self):
        print("I'm a Car")

class Yugo(Car):
    # 함수 오버라이드,재정의
    def exclaim(self):
        print("I'm a Yugo! Much like a Car, but more Yugo-ish.")

give_me_a_car = Car()
give_me_a_yugo = Yugo()

give_me_a_car.exclaim()
give_me_a_yugo.exclaim()
# Out:
# I'm a Car
# I'm a Yugo! Much like a Car, but more Yugo-ish.

# %%
class Car():
    def exclaim(self):
        print("I'm a Car")

class Yugo(Car):
    # 함수 오버라이드
    def exclaim(self):
        print("I'm a Yugo! Much like a Car, but more Yugo-ish.")
    # 하위 클래스에서 추가된 함수
    def need_a_push(selfs):
        print("A little help here?")

give_me_a_car = Car()
give_me_a_yugo = Yugo()

give_me_a_car.exclaim()
give_me_a_yugo.exclaim()
give_me_a_yugo.need_a_push() # 하위 클래스에 추가된 함수 호출
# Out:
# I'm a Car
# I'm a Yugo! Much like a Car, but more Yugo-ish.
# A little help here?

# %%
# 이러한 것들이 필요한 이유를 생각해봅시다.

# %% [markdown]
# ### 7.3.5 패키지 사용하기

# %%
import urllib.request

import urllib.request as ur #줄임말....


response = urllib.request.urlopen('http://www.google.co.kr')
response.status
# Out:
# 200

# %% [markdown]
# urllib.request.urlopen은 URL을 여는 함수인데 URL 열기에 성공하면 response.status의 값이 200이 나옵니다.
# 이 200은 HTTP 상태 코드이며 웹 서버가 요청을 제대로 처리했다는 뜻입니다.
# import as로 패키지 모듈 이름 지정하기

# %%
import urllib.request as r                             # urllib 패키지의 request 모듈을 가져오면서 이름을 r로 지정
response = r.urlopen('http://www.google.co.kr')        # r로 urlopen 함수 사용
response.status
# Out:
# 200

# %% [markdown]
# ### 7.3.6 from import로 패키지의 모듈에서 일부만 가져오기

# %%
from urllib.request import Request, urlopen        # urlopen 함수, Request 클래스를 가져옴
req = Request('http://www.google.co.kr')           # Request 클래스를 사용하여 req 생성
response = urlopen(req)                            # urlopen 함수 사용
response.status
# Out:
# 200

# %% [markdown]
# urlopen 함수에 URL을 바로 넣어도 되고,
# Request('http://www.google.co.kr') 와 같이 Request 클래스에 URL을 넣은 뒤에 req를 생성해서 urlopen 함수에 넣어도 가능하다.

# %% [markdown]
# #### urllib의 request 모듈에서 모든 변수, 함수, 클래스를 가져오기

# %% [markdown]
# from urllib.request import *                    # urllib의 request 모듈에서 모든 변수, 함수, 클래스를 가져옴
# req = Request('http://www.google.co.kr')        # Request를 사용하여 req 생성
# response = urlopen(req)                         # urlopen 함수 사용
# response.status

# %% [markdown]
# ### 7.3.7 종합적으로...

# %%
객체지향 프로그래밍(Object-Oriented Programming)
클래스 개념이해...
인스턴스 생성하기(Instantiation)
클래스 변수(Class Variables,Member Variable,Field)
클래스 메서드(Methods)
생성자(Constructor)
인스턴스 변수(Instance Variables)
인스턴스 변수 사용, self

# %% [markdown]
# ###  클래스는 자료형을 위한 일종의 템플릿이라고 생각하면 된다.
# ###  클래스 안에는 다양한 유형의 정보가 담겨 있고, 우리가 자료형과 어떻게 상호작용할 것인지 적혀 있다.

# %%
class Test:
    title = "Test"
    
    def __init__(self, name): 
        self.name = name ##클래스가 갖고있는 기본 필드(attribute)를 여기에서 바로 선언 가능....
        
    def print_title(self,title):  ### self 먼저 들어간다...
        print(title)
    
    def print_name(self):
        print(self.name)
    
t1 = Test('hong')   ### 인스턴스화 한다... 

#print(t1.title)
#t1.print_title('test')

t1.print_name()


class TestStrong(Test):
    my_title='my title'
    
    def print_pname(self):
        print(self.name)
        

ts1 = TestStrong('strong name')

ts1.print_pname()
# Out:
# hong
# strong name

# %% [markdown]
# ### 돌발문제
#
# Calculator라는 클래스를 만들어라.
#
# Calculator는 result라는 필드를 갖고 있다. 초기값은 0
#
# 함수는 더하기,빼기,곱하기,나누기를 하는 함수를 만들어라.
#
# 모든 함수는 두개의 값을 입력받는다...
#
# 각 함수의 처리결과는 result에 저장하고 프린트한다...
#
# 이 클래스를 만들고 인스턴스화해서 테스트 코드를 작성하세요...

# %%
a = float(input('첫번째 값을 입력하세요'))
b = float(input('두번째 값을 입력하세요'))

class Calculator:
    result = 0
    def __init__(self):
        pass
    
    def add(self,a,b):
        result = a + b
        return result
    
cal = Calculator()

res = cal.add(a,b)

print(res)
# Out:
# 첫번째 값을 입력하세요 2
# 두번째 값을 입력하세요 3
# 5.0

# %% [markdown]
# ![image.png](attachment:7843a00f-16df-4770-8c81-94c1a2075e5b.png)

# %% [markdown]
# ![image.png](attachment:64f23f86-5a59-4f56-a47e-975fbbcdf1ed.png)

# %%
import math


class Circle:
    radius =0
    cx=0
    cy=0

    def __init__(self, radius, cx, cy):
        self.radius = radius
        self.cx = cx
        self.cy = cy
    def area(self):
        return self.radius*self.radius*math.pi
    def center(self):
        return self.cx,self.cy
    

def main():
    radius =0
    cx=0
    cy=0
    print("정보를 입력하세요")
    radius=int(input("반지름:"))
    cx=int(input("x좌표:"))
    cy=int(input("y좌표:"))
    circle = Circle(radius,cx,cy)

    #함수호출
    print("원의 넓이: "+str(circle.area()))
    print("중심좌표: "+str(circle.center()))


if  __name__ == "__main__":
    main()
# Out:
# 정보를 입력하세요
# 반지름: 3
# x좌표: 3
# y좌표: 2
# 원의 넓이: 28.274333882308138
# 중심좌표: (3, 2)

# %% [markdown]
# ![image.png](attachment:5b886283-c2fa-4904-902f-b40b91124db6.png)

# %% [markdown]
# ### 돌발문제
#
#
# 자판기 클래스 만들고...
# 사람을 클래스 만들고...
#
# 사람이 돈을 갖고있고... 사람이 자판에서 커피를 뽑아 먹는다...
#
# 자판기 기능을 프로그램으로 만드세요...

# %%
class Zapangi:
 
    def __init__(self):
        self.p = {'콜라':500, '사이다':400, '환타':600}
        self.n = {1:'콜라', 2:'사이다', 3:'환타'}
        self.money = 0      
 
    def showmenu(self):
        print('[메뉴정보]')
        i = 1
        for k, v in self.p.items():
            print(str(i)+'.', k, v, '원')
            i+=1
        print()
 
 
    def inputmoney(self):
        while True:
            try:
                self.money += int( input('돈 투입:') )
            except Exception as e:
                print(e)
                continue
            else:
                print('투입금액:', self.money)
                print()
                break
 
 
    def buy(self):
        try:
            n = int(input('번호선택(종료:0):'))
        except Exception as e:
            print(e)
        else:
            if n == 0:
                return False       
 
            if n>=1 and n<=3:
 
                if self.money >= self.p[ self.n[n] ]:
                    print( self.n[n], '구입완료' )
                    self.money = self.money - self.p[ self.n[n] ]
                    print('잔액:', self.money)
                else:
                    print('잔액부족')
                    self.inputmoney()
               
            else:
                print('잘못된 번호')
 
        return True
 
 
z = Zapangi()
z.showmenu()
z.inputmoney()
 
while z.buy():    
    print()
 
print('자판기 종료')
print('반환 : ', z.money, '원')
# Out:
# [메뉴정보]
# 1. 콜라 500 원
# 2. 사이다 400 원
# 3. 환타 600 원
# 돈 투입: 3000
# 투입금액: 3000
# 번호선택(종료:0): 2
# 사이다 구입완료
# 잔액: 2600
# 번호선택(종료:0): 3
# 환타 구입완료
# 잔액: 2000
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 4
# 잘못된 번호
# 번호선택(종료:0): 0
# 자판기 종료
# 반환 :  2000 원

# %%
# 커피 클래스
class MilkCoffee:
    price = 400
    def __init__(self): #생성자...
        print('밀크커피!')
class BlackCoffee:
    price = 300
    def __init__(self): #생성자
        print('블랙커피!')
        
# 인간 클래스
class Customer:
    def __init__(self,money):
        self.money = money
        print(f'나는 {self.money}원을 가지고 있다')
        
    def getMoney():
        return self.money
    def setMoney(newmoney):
        self.money = newmoney
        
# 자판기 클래스
class vendor:
    
    black_coffee = BlackCoffee
    milk_coffee = MilkCoffee
    
    def __init__(self):
        print('자판기 생성')
        

    def make_milk_coffee(self,cust):
        if cust.money >= self.milk_coffee.price:
            cust.money = cust.money - self.milk_coffee.price
            get_milk = MilkCoffee()
            print(f'잔돈은 {cust.money}입니다')
        else:
            print("돈이 없으면 커피는 없지")

    def make_black_coffee(self, cust):
        if cust.money >= self.black_coffee.price:
            cust.money = cust.money - self.black_coffee.price
            get_black = BlackCoffee()
            print(f'잔돈은 {cust.money}입니다')
        else:
            print("돈 더 갖고오십쇼")

# 인간 검증기
def valid_money(): 
    while True:
        try:
            money = int(input("돈을 넣어주세요..."))
        except:
            print("돈을 정수형으로 넣어야지")
            continue
        break
  
    c = Customer(money)
    
    return c

c = valid_money()
v = vendor()

v.make_milk_coffee(c)
v.make_black_coffee(c)

print(c.money)
# Out:
# 돈을 넣어주세요... 천원
# 돈을 정수형으로 넣어야지
# 돈을 넣어주세요... 1000
# 나는 1000원을 가지고 있다
# 자판기 생성
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15284\3653400588.py in <module>
#      63 v = vendor()
#      64
# ---> 65 v.get_milk_coffee(c)
#      66 v.get_black_coffee(c)
#      67
#
# AttributeError: 'vendor' object has no attribute 'get_milk_coffee'

# %%
money = int(input('돈을 입력하시오.'))
cup = int(input('몇 잔을 추출하나요?'))
coffee_price = 300

class Coffee:
    result1 = 0
    
    def __init__(self):
        pass
    
    def mul(self,cup,coffee_price):
        result1 = cup * coffee_price
        return result1
    
    def diff(self,money, result1):
        result2 = money - result1
        return result2
    
co = Coffee()
pocket = co.diff(money,coffee_price*cup)
print('남은 돈은 {0}원입니다.'.format(pocket))
# Out:
# 돈을 입력하시오. 1000
# 몇 잔을 추출하나요? 3
# 남은 돈은 100원입니다.

# %%
class Person:
    
    money=0
    
    def __init__(self, money):
        self.money = money
        
    def get_money(self):
        return self.money
    
    def minus_money(self, money):
        self.money -= money
        
    def use_vending_machine(self, v):
        vp = v.get_price()
        vs = v.get_stock()
        pm = self.get_money()
    
        if vs >= 1:
            if pm >= vp:
                print("[System] 자판기를 이용합니다. 커피의 가격은 " + str(vp) +"원 입니다.")
                self.minus_money(vp)
                v.minus_stock(1)
                pm = self.get_money()
                vs = v.get_stock()
                print("[Info] 커피 구매 후 잔액 : " + str(pm) +"원")
                print("[Info] 자판기 남은 커피 재고 :", vs)
            else:
                print("[Error] 잔액이 부족하여 커피를 구매할 수 없습니다")
        else:
            print("[Error] 재고가 부족하여 커피를 구매할 수 없습니다")
        
class VendingMachine:
    
    stock=0
    price=0
    
    def __init__(self, stock, price):
        self.stock = stock
        self.price = price
        
    def get_price(self):
        return self.price
        
    def get_stock(self):
        return self.stock
    
    def minus_stock(self, stock):
        self.stock -= stock
        
p_money = int(input("당신이 소지한 금액을 입력해주세요"))
v_info = list(map(int, input("자판기의 커피 재고와 가격을 '재고 가격' 형식으로 적어주세요 (예시 : 20 500)").split(' ')))

p = Person(p_money)
v = VendingMachine(v_info[0], v_info[1])

pm = p.get_money()
vs = v.get_stock()
vp = v.get_price()

print("설정한 소지금 :", pm)
print("설정한 자판기의 커피 재고와 가격 :", vs, vp)

while True:
    question = input("커피를 구매하시겠습니까? : 예(Y) / 아니오(N)")
    if question == "Y":
        p.use_vending_machine(v)
    elif question == "N":
        print("[System] 이용해주셔서 감사합니다 안녕히 가세요")
        break
    else:
        print("[Error] 잘못된 입력입니다.")
# Out:
# 당신이 소지한 금액을 입력해주세요 1000
# 자판기의 커피 재고와 가격을 '재고 가격' 형식으로 적어주세요 (예시 : 20 500) 5 200
# 설정한 소지금 : 1000
# 설정한 자판기의 커피 재고와 가격 : 5 200
# 커피를 구매하시겠습니까? : 예(Y) / 아니오(N) Y
# [System] 자판기를 이용합니다. 커피의 가격은 200원 입니다.
# [Info] 커피 구매 후 잔액 : 800원
# [Info] 자판기 남은 커피 재고 : 4
# 커피를 구매하시겠습니까? : 예(Y) / 아니오(N) N
# [System] 이용해주셔서 감사합니다 안녕히 가세요

# %%
class VendingMachine:
 
    def __init__(self):
        self.p = {'콜라':500, '사이다':400, '환타':600,'하이트',1200}
        self.n = {1:'콜라', 2:'사이다', 3:'환타',4:'하이트'}
        
        self.money = 0      
 
    def showmenu(self):
        print('[메뉴정보]')
        i = 1
        for k, v in self.p.items():
            print(str(i)+'.', k, v, '원')
            i+=1
        print()
 
 
    def inputmoney(self):
        while True:
            try:
                self.money += int( input('돈 투입:') )
            except Exception as e:
                print(e)
                continue
            else:
                print('투입금액:', self.money)
                print()
                break
 
 
    def make(self):
        try:
            n = int(input('번호선택(종료:0):'))
        except Exception as e:
            print(e)
        else:
            if n == 0:
                return False       
            if 1<= n <=3:
      #      if n>=1 and n<=3:
 
                if self.money >= self.p[ self.n[n] ]:
                    print( self.n[n], '구입완료' )
                    self.money = self.money - self.p[ self.n[n] ]
                    print('잔액:', self.money)
                else:
                    print('잔액부족')
                    self.inputmoney()
               
            else:
                print('잘못된 번호')
 
        return True
 
 
z = VendingMachine()
z.showmenu()
z.inputmoney()
 
while z.make():    
    print()
 
print('자판기 종료')
print('반환 : ', z.money, '원')
# Out:
# [메뉴정보]
# 1. 콜라 500 원
# 2. 사이다 400 원
# 3. 환타 600 원
# 돈 투입: 1000
# 투입금액: 1000
# 번호선택(종료:0): 2
# 사이다 구입완료
# 잔액: 600
# 번호선택(종료:0): 3
# 환타 구입완료
# 잔액: 0
# 번호선택(종료:0): 1
# 잔액부족
# 돈 투입: 0
# 투입금액: 0
# 번호선택(종료:0): 0
# 자판기 종료
# 반환 :  0 원

# %%
# 커피 클래스
class Coffee:
    def __init__(self,name,price): #생성자...
        
        self.name = name
        self.price = price
        
        print(name,':',price)
        
milk_coffee = Coffee('밀크',300)
black_coffee = Coffee('블랙',500)

# 인간 클래스
class Customer:
    def __init__(self,money):
        self.money = money
        print(f'나는 {self.money}원을 가지고 있다')
        
    def getMoney():
        return self.money
    def setMoney(newmoney):
        self.money = newmoney
        
# 자판기 클래스
class vendor:

    def __init__(self):
        print('자판기 생성')
        

    def make_milk_coffee(self,cust):
        if cust.money >= milk_coffee.price:
            cust.money = cust.money - milk_coffee.price
            get_milk = MilkCoffee()
            print(f'잔돈은 {cust.money}입니다')
        else:
            print("돈이 없으면 커피는 없지")

    def make_black_coffee(self, cust):
        if cust.money >= black_coffee.price:
            cust.money = cust.money - black_coffee.price
            get_black = BlackCoffee()
            print(f'잔돈은 {cust.money}입니다')
        else:
            print("돈 더 갖고오십쇼")

# 인간 검증기
def valid_money(): 
    while True:
        try:
            money = int(input("돈을 넣어주세요..."))
        except:
            print("돈을 정수형으로 넣어야지")
            continue
        break
  
    c = Customer(money)
    
    return c

c = valid_money()
v = vendor()

v.make_milk_coffee(c)
v.make_black_coffee(c)

print(c.money)
# Out:
# 밀크 : 300
# 블랙 : 500
# 돈을 넣어주세요... 1000
# 나는 1000원을 가지고 있다
# 자판기 생성
# 밀크커피!
# 잔돈은 700입니다
# 블랙커피!
# 잔돈은 200입니다
# 200

# %%
class VendingMachine:
 
    def __init__(self):
        self.p = {1:['콜라',500],2:['사이다',400],3:['환타',600]}

        self.money = 0      
 
    def showmenu(self):
        print('[메뉴정보]')
 
        for k, infor in self.p.items():
            print(str(k)+'.', infor[0],infor[1], '원')
        print()
 
 
    def inputmoney(self):
        while True:
            try:
                self.money += int( input('돈 투입:') )
            except Exception as e:
                print(e)
                continue
            else:
                print('투입금액:', self.money)
                print()
                break
 
 
    def make(self):
        try:
            n = int(input('번호선택(종료:0):'))
       
        except Exception as e:
            print(e)
        else:
            if n == 0:
                return False       
            if 1<= n <=3:
                if self.money >= self.p[n][1]:
                    print( self.p[n][0], '구입완료' )
                    self.money = self.money - self.p[n][1]
                    print('잔액:', self.money)
                else:
                    print('잔액부족')
                    self.inputmoney()
               
            else:
                print('잘못된 번호')
 
        return True
 
 
z = VendingMachine()
z.showmenu()
z.inputmoney()
 
while z.make():    
    print()
 
print('자판기 종료')
print('반환 : ', z.money, '원')
# Out:
# [메뉴정보]
# 1. 콜라 500 원
# 2. 사이다 400 원
# 3. 환타 600 원
# 돈 투입: 1000
# 투입금액: 1000
# 번호선택(종료:0): 3
# 환타 구입완료
# 잔액: 400
# 번호선택(종료:0): 3
# 잔액부족
# 돈 투입: 2
# 투입금액: 402
# 번호선택(종료:0): 0
# 자판기 종료
# 반환 :  402 원

# %% [markdown]
# ### 파이썬에서는 리턴값을 1개 이상 보낼 수 있다....

# %%
def return_sample():
    return 1,2


a,b = return_sample()

print(a,b)
# Out:
# 1 2

# %%
import random

x = random.random() ### 한번 random을 수행할때마다 다른 값을 만들어 준다.

print(x)
# Out:
# 0.5081193008200012

# %%
y = random.uniform(0,10)

print(y)
# Out:
# 2.8792261226984586

# %%
i = random.randint(0,3)
print(i)
# Out:
# 1

# %% [markdown]
# ### 돌발문제
#
# random.randint함수를 사용해서 가위바위보 게임을 만들어라...
#
# 1. 가위(1),바위(2),보(3) 중 하나를 유저가 숫자 선택
# 2. random에서 1,2,3중 하나를 생성
# 3. 제어문으로 if 승,패를 결정을 프린트...

# %%
import random as r
# 내 손 로직
def user_hand():
    while True:
        user_hand = input('가위 바위 보 중에서 입력해 주십사')
        if user_hand == '가위' or user_hand =='보' or user_hand == '바위':
            break
        else:
            print("다시 입력해주세요")
            #continue
            
    return user_hand


# 게임 로직
def game_start(user): ##user 유저가 결정한 가위,바위,보
    
    a = r.randint(0, 2)
    hand = ['가위', '바위', '보']
    
    if user == hand[a]:
        print(f'나는{user} 상대는 {hand[a]}')
        print("비겼다..")
    elif user=='가위' and hand[a] == '보':
        print(f'나는{user} 상대는 {hand[a]}')
        print('이겼다..')
    elif user=='바위' and hand[a] == '가위':
        print(f'나는{user} 상대는 {hand[a]}')
        print('이겼다..')
    elif user == '보' and hand[a] == '바위':
        print(f'나는{user} 상대는 {hand[a]}')
        print('이겼다..')
    else:
        print(f'나는 {user} 상대는 {hand[a]}')
        print("졌다...")

game_start(user_hand())

# %%
import random

print('Commencing rock, paper, scissors.')
print('1: rock, 2: paper, 3: scissors')

user_input = int(input('Select a number.'))
                 
computer_choice = random.randint(1, 3)
                 
print('Computer', 'picked', computer_choice)
                 
if user_input == 1:
    if computer_choice == 1:
        print('Draw!')
    elif computer_choice == 2:
        print('Lose!')
    else:
        print('Win!')
elif user_input == 2:
    if computer_choice == 1:
        print('Win!')
    elif computer_choice == 2:
        print('Draw!')
    else:
        print('Lose!')
elif user_input == 3:
    if computer_choice == 1:
        print('Lose!')
    elif computer_choice == 2:
        print('Win!')
    else:
        print('Draw!')
else:
    print('Incorrect number')

# %%
import random

# function to determine the winner
def determine_winner(player_choice, computer_choice):
    if player_choice == computer_choice:
        return "Tie!"
    elif (player_choice == "rock" and computer_choice == "scissors") or \
        (player_choice == "paper" and computer_choice == "rock") or \
        (player_choice == "scissors" and computer_choice == "paper"):
        return "You win!"
    else:
        return "Computer wins!"

# possible choices for the game
choices = ["rock", "paper", "scissors"]

# main game loop
while True:
    print("Choose your weapon: ")
    print("1. Rock")
    print("2. Paper")
    print("3. Scissors")
    
    player_choice = input("Enter your choice (1-3): ")

    # check if player entered a valid choice
    if player_choice not in ["1", "2", "3"]:
        print("Invalid choice! Try again.")
        continue

    # convert player's choice to corresponding string value
    player_choice = choices[int(player_choice) - 1]
    print("You chose:", player_choice)

    # computer chooses a random option
    computer_choice = random.choice(choices)
    print("Computer chose:", computer_choice)

    # determine the winner
    result = determine_winner(player_choice, computer_choice)
    print(result)

    # ask if the player wants to play again
    play_again = input("Do you want to play again? (y/n): ")
    if play_again.lower() != "y":
        break

print("Thanks for playing!")

# %% [markdown]
# random.choice(seq)
#
# choice 함수는 매개변수로 seq 타입을 받습니다. 시퀀스 데이터 타입은 문자열(string), 튜플, range, 리스트 타입들을 말합니다.
#
# 시퀀스 함수는 인자로 받은 리스트, 튜플, 문자열, range 에서 무작위로 하나의 원소를 뽑습니다.
#
# 만약, 비어있는 시퀀스 타입의 객체를 인자로 넣는다면 (ex. 리스트가 비어있다면) indexError 의 예외가 발생합니다.

# %% [markdown]
# ### 미션
#
# ### 여러분들이 만들었던 클래스들을 모듈화해서 사용하세요...
