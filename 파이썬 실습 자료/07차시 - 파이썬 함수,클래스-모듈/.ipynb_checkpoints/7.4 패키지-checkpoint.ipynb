# %% [markdown]
# ### 7.4 패키지
#
# 패키지(Packages)는 도트(.)를 사용하여 파이썬 모듈을 계층적(디렉터리 구조)으로 관리할 수 있게 하는 것.
#
# 예를 들어 모듈 이름이 A.B인 경우에 A는 패키지 이름이 되고 B는 A 패키지의 B모듈이 된다.
#
# 모듈, 또느 클래스로 이루어진 디렉토리/파일 형태로 만들어 진다.

# %% [markdown]
# 이처럼 다른 프로그램 제작에 사용하기 위해 미리 만들어진 프로그램의 집합을 라이브러리(library)라고 한다.
#
# 파이썬에서는 라이브러리라는 용어 대신 패키지(package)라는 말을 주로 사용한다.

# %% [markdown]
# #### 7.1.1 설치 방법
#
# C, C++, 자바 같은 언어는 새로운 라이브러리를 설치할 때 소스코드나 바이너리를 내려받아야 하고 프로그램 내에 정확히 카피해서 컴파일 해야함.
#
# 파이썬은 모든 패키지를 한 서버에 등록해서 간단한 명령어만으로 패키지를 쉽게 내려받아 설치할 수 있다.

# %% [markdown]
# pip 패키지 관리자를 사용할 때는 pip list 명령으로 설치된 패키지 목록을 볼 수 있다.

# %% [markdown]
# ![image.png](attachment:b32fd061-1f65-4e99-9fb4-25e8d1db6e6c.png)

# %% [markdown]
# ### 7.1.2 패키지 만들기

# %% [markdown]
# 모듈들은 넣어둔 디렉토리명이 패키지명이 됩니다.
#
# 패키지내 각 디렉토리에는 __init__.py 가 반드시 존재해야 합니다. __init__.py 파일은 비어있을수도 있고, 패키지내에 포함된 모듈들의 정보를 제공하기도 합니다.
#
# 예) food 패키지 구조

# %% [markdown]
# ![image.png](attachment:17f5d6c8-92cf-470f-a340-881712ae34af.png)

# %% [markdown]
# food 패키지 아래에는 breakfast, lunch, dinner 세개의 모듈이 있습니다.
# food 아래에 __init__.py 파일내에는 __all__, __version__ 등이 들어갑니다.
#
# 예) __all__ = ["breakfast","lunch","dinner"]
#
# __all__ 은 import * 했을때 어떤 모듈을 임포트 할지 정의합니다.
# import food 하게 되면 food 패키지 내의 모든 모듈들이 임포트되지만 하위 패키지의 모듈은 임포트 되지 않습니다.
#
# 사용할때는 직접 임포트 해야 합니다.
