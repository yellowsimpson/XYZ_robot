# %% [markdown]
# # 1 파이썬 개요

# %% [markdown]
# ## 1.1 설치하기

# %% [markdown]
# ### 1.1.1 파이썬 설치하기

# %% [markdown]
# www.python.org에서 다운로드 메뉴 - Python 3.9.5 최신 선택해서 다운로드
#
# 설치 과정에서 "Add Python 3.9.5 to Path" 반드시 체크
#
#
# ![image.png](attachment:c79b65d5-58d2-40be-b3b1-20354ba1a94c.png)

# %% [markdown]
# ### 1.1.2 설치 확인

# %% [markdown]
# ![image.png](attachment:baa853e9-d45c-426c-b12b-edebaacb338d.png)

# %% [markdown]
# 윈도우키 + R을 눌러서 나오는 창에 powershell이라고 치고, 확인을 눌러서 powershell실행
#
# powershell화면에서 python이라고 입력해서 오류가 나오지 않으면 설치 성공
#
#
# ![image.png](attachment:0c4755b2-e4ab-42e6-bd1e-6b66a3f83319.png)

# %% [markdown]
# ### 1.1.3 아나콘다 설치

# %% [markdown]
# 주피터 노트북 및 인공지능 개발을 위한 스파이더 설치를 위함.
#
# https://www.anaconda.com/products/individual#windows
#
# ![image.png](attachment:ece96cc2-84b4-48a2-8eb1-0b68bcf13b1b.png)

# %% [markdown]
# ### 설치 확인

# %% [markdown]
# ![image.png](attachment:11247657-c7b0-428c-8ba6-852d310b9043.png)

# %% [markdown]
# ### 1.1.4 주피터 노트북 실행

# %% [markdown]
# ![image.png](attachment:09b99caa-d5fc-4f94-8511-3eec7cfa33a7.png)

# %%
# 주피터 노트북 사용 방법
#마지막으로 브라우저의 url의 tree 부분을 lab를 변경하시기 바랍니다.

# %% [markdown]
# ### 1.1.5 주피터 노트북 사용하기
#
# markup과 code 설명,코드 추가하기
# 그럼 코드를 작성하기 전에 설명부터 넣어보겠습니다.
# 메뉴의 드롭다운 목록에서 Markdown을 선택하고 빈칸에 다음 내용을 입력합니다.
# #은 제목이라는 뜻이며 #이 하나씩 늘어날 수록 하위 제목이 됩니다.

# %% [markdown]
# ![image.png](attachment:718ea5a1-fc93-451c-8904-a410bf18435f.png)

# %%
# 기본 메뉴 및 설명하기 , 사진 붙이기

# %% [markdown]
# ### 1.1.6 파이썬 코드 실행하기

# %% [markdown]
# ### 코드 실행 버튼 이해하기
# ![image.png](attachment:d9fbc50f-9e77-4165-8eb2-23bb0c94ce80.png)

# %%
#run,stop,save,comment 등 실습
print('안녕')
# Out:
# 안녕
