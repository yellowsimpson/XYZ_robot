# %% [markdown]
# # 1.1 파이썬 기본 구조

# %% [markdown]
# ### 1.1.1 코드 시작

# %% [markdown]
# 간결함의 철학은 파이썬 문법에도 그대로 적용되어 파이썬 프로그래밍을 하는 사람들은 잘 정리되어 있는
# 소스 코드를 볼 수 있다.
# 다른 사람이 작업한 소스 코드도 한눈에 들어와 이해하기 쉽기 때문에 공동 작업과 유지 보수가 아주 쉽고 편하다.

# %%
# 주석: # 뒤에 나온 부분은 주석으로 실행되지 않습니다.  
print("홍범도")
# Out:
# 홍범도

# %% [markdown]
# 집을 짓는 것과 같다

# %% [markdown]
# ![image.png](attachment:daa28d28-066a-417e-9643-900ad4632164.png)

# %% [markdown]
# ![image.png](attachment:19dc06d7-de2b-44c9-8e62-0ce91f3503a1.png)

# %% [markdown]
# ### 1.1.2 MAIN 함수

# %% [markdown]
# ![image.png](attachment:ad5349ec-ecac-4e76-97bc-91892b7f8e47.png)

# %% [markdown]
# 주의할점은 tab입니다.
# <br>메인함수는 Python Main 함수는 모든 프로그램의 시작점입니다.
# <br>프로그램이 실행되면 순차적으로 파이썬 인터프리터가 코드를 순차적으로 실행합니다.
# <br>Main 함수는 Python 파일로 만들어진 프로그램으로 실행될 때만 실행됩니다.
# <br>모듈로 가져온 경우 기본 기능을 실행하지 않습니다.

# %%
#프로그램 시작함수는 __main__에서

print('hello')

if __name__ == '__main__':
    print('Hello World')
    
print('end')
# Out:
# hello
# Hello World
# end

# %% [markdown]
# 여러 사람들이 같이 프로젝트를 할 때는, 통일된 방식으로 문서를 짜는 게 가독성과 유지 보수 면에서 편리합니다.

# %% [markdown]
# https://zerosheepmoo.github.io/pep8-in-korean/doc/code-lay-out.html#%E1%84%83%E1%85%B3%E1%86%AF%E1%84%8B%E1%85%A7%E1%84%8A%E1%85%B3%E1%84%80%E1%85%B5

# %% [markdown]
# ### 1.1.3 함수 생성, 호출

# %% [markdown]
# 함수란 프로그래밍 코드를 블럭으로 만들어 놓고 반복되는 코드를 줄여주기 위해 특정 코드를 함수안에 정의하고, 그 코드를 함수명칭을 호출함으로써 코드를 실행하게 해줍니다.
#
# 함수는 붕어빵 틀과 같습니다.
#
# 함수의 구조,문법
#
# return은 생략될 수 있습니다. return이 수행되면 함수가 종료됩니다.
#
# def 함수명(파라미터):
#
#     실행될 코드 1
#        return 결과 값 1 ## return을 만나면 함수가 종료된다.
#     실행될 코드 2
#     return 결과 값 2

# %% [markdown]
# ![image.png](attachment:35fe40e1-4a45-47c6-aca5-60fb45018cb5.png)

# %% [markdown]
# ### 인수:파라미터,Parameter : 함수에 어떤 정보를 넣어주는 기능
#
# ### 재활용성

# %%
print('시작') 
def odd_or_even(n,x=True): #함수의 선언..../붕어빵 틀을 만든다.
    if n % 2 == 0:
        print("짝수")
        return
    print("홀수")  
    
odd_or_even(10)    #함수를 콜, 호출 해준다..
odd_or_even(11)
odd_or_even(12)

print('끝')
# Out:
# 시작
# 짝수
# 홀수
# 짝수
# 끝

# %%
미션 < 환율을 사용하여 바꾸고자하는 돈과 금액(달러)을 입력으로하고 결과는 원화로 출력되는 프로그램을
작성하세요, main함수를 사용하세요. 예를 들어 환율이 1300원이고 1달러를 원하면 출력으로 1300원을 출력
출결과는 천단위로 컴마를 찍어주세요.

# %%
def exchange(rate,dalar):
    print('-'*10)
    return rate * dalar

def block():
    pass
won = exchange(132.1,100)
won = int(won)

won = format(won,',d')

print(type(won))

print(won)
# Out:
# ----------
# <class 'str'>
# 13,210

# %% [markdown]
# ### format() 문법
#
# format(number, ',d/f')
# number --> format을 적용하여 천단위 콤마를 찍을 숫자입니다.
#
# ',d/f' --> format을 적용할때 받은 number의 자료형이 무엇인지 입력하고 천단위 콤마를 찍는다는 의미입니다.
#
# d는 정수이고, f는 실수입니다.

# %% [markdown]
# 사용자 함수를 정의해서 사용시 지켜야할 문법
#
# 설명문을 세개("""함수 설명""")로 함수에 대한 부가 설명(Docstring)을 넣어주고 시작합니다.
#
# 작성자 이름, 작성 날짜/변경, 변경내용 등,
#
# 1. 첫 줄에는 def 로 시작하며
#
# 2. 사용자 정의 함수 이름을 쓰고,
#
# 3. 괄호 안에는 매개변수 목록을 쓰며, 끝은 콜론(:)을 써줍니다.
#
# 4. 다음줄 부터는 들여쓰기(indentation)을 꼭 해주어야 하며,
#
#
#
# 5. 실행하고자 함는 작업에 대해서 코드블록을 작성합니다.
#
# 6. 마지막에 return 뒤에 반환하고자 하는 결과값을 써주면 됩니다. 반환할 값이 없으면 return 은 생략 가능합니다.

# %% [markdown]
# ### 함수 디폴트값 사용,정의에대한 값을 넣어주지 않을 때 자동으로 사용되는 값...

# %%
def default_test(i=0,j=1):
    print(i+j)
    
default_test(2)
# Out:
# 3

# %%
def add(a,b):
    return a + b

# %%
def my_average(x1, x2):

    """

    This function calculates average value of two numbers

    x1: first input number

    x2: second input number

    """

    if isinstance(x1, (int, float)) and isinstance(x2, (int, float)):

        avg_val = (float(x1) + float(x2))/2

        return avg_val

    else:

        print("This is not a number")

# %%
my_average(2, 5)
# Out:
# 3.5

# %% [markdown]
# 파라미터의 사용 방법에 대하여 알아봅시다.

# %% [markdown]
# #### 예외 처리: 어떤 에러가 발생할 수 있기때문에 , 그러한 에러가 발생했을때 처리하는 방법을 제시한다.

# %% [markdown]
# name 'y' is not defined : y에대한 선언을 하지 않았을때 발생....

# %%
y = 0 #정의한다... 변수에대한 값을 선언하다...
print(y)
# Out:
# 0

# %%
print('hi')
print(x)
print('end')
# Out:
# hi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7456\3490795419.py in <module>
#       1 print('hi')
# ----> 2 print(x)
#       3
#       4
#       5 print('end')
#
# NameError: name 'x' is not defined

# %%
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
print("시작")

def my_div(a, b):
    result = 0
    try:
        result = a / b
    except:
        pass
    return result


print(my_div(2, 2))
print(my_div(2, 0))

print("종료")
# Out:
# 시작
# 1.0
# 0
# 종료

# %% [markdown]
# #### 리턴....

# %%
sum = 0  ## sum은 global변수(전역) 변수

def add(a,b):
    sum = a + b #sum은 로컬이다.... add라는 함수(블럭)내에서만 의미가 있다... 정의된다..
    return sum  ## 어떤 함수(블럭)을 실행하고 그 결과를 호출한 명령어에 돌려준다...
    
    
sum = add(1,2)
# Out:
# 3

# %% [markdown]
# ### 1.1.4 실행하기

# %%
def Para(state="exist"):
    print("Parameter is " + state)
    
Para()
# Out:
# Parameter is exist

# %% [markdown]
# 함수가 인자를 받는다면, 아래와 같이 변수 이름을 입력하면 됩니다. 호출할 때는 Para("exist")처럼 괄호 안에 인자를 전달합니다.

# %%
def Hello(name="팅커벨"):
    print("Hello, " + name)


Hello()
Hello("도깨비")
# Out:
# Hello, 팅커벨
# Hello, 도깨비

# %%
if __name__ == '__main__':
   Hello()
   print('Hello World')
# Out:
# Hello, 팅커벨
# Hello World

# %% [markdown]
# 함수 인자에 기본으로 사용하는 값을 설정하면, 함수 호출 시 인자를 전달하지 않을 때 그 값이 사용됩니다. 이것을 디폴트 매개변수라고 합니다.
#
# 디폴트 매개변수는 name="팅커벨"처럼 기본 값을 설정하며, hello()처럼 인자 없이 호출할 때 name에 기본으로 설정한 값이 사용됩니다.
#
# hello("도깨비")처럼 명시적으로 인자를 전달하면, 디폴트 값 대신에 이 값이 사용됩니다.

# %%
def Return():
    
    return ["hello", 100]


result = Return()
print(result)
print(result[0])
print(result[1])
# Out:
# ['hello', 100]
# hello
# 100

# %% [markdown]
# 함수는 하나의 객체를 리턴하지만, 아래와 같이 여러 값을 갖고 있는 리스트를 리턴하여 2개 이상의 값을 리턴하도록 만들 수 있습니다.

# %% [markdown]
# ### 1.1.5 내장함수

# %% [markdown]
# Python 인터프리터에는 항상 사용할 수 있는 여러 함수와 유형이 내장되어 있습니다.

# %% [markdown]
# ![download.png](attachment:28380b09-48c8-41d4-9f4d-27b1bfdca21d.png)

# %%
abs(-3)
# Out:
# 3

# %%
x = input('이름을 입력하세요')

print('당신의 이름은 ',x, '입니다.')
# Out:
# 이름을 입력하세요 홍길동
# 당신의 이름은  홍길동 입니다.

# %%
pow(3,3)
# Out:
# 27

# %%
pwd()
# Out:
# 'C:\\Users\\DESK-1\\파이썬 학습\\파이썬 학습\\01차시_파이썬 이해 및 설치'

# %%
len("hello")
# Out:
# 5

# %%
round(3.5)
# Out:
# 4
